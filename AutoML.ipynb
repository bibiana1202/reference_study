# %%
 # !pip install pycaret==1.0
 # !pip install scipy==1.2 --upgrade
# Out:
# Collecting pycaret==1.0
#   Downloading pycaret-1.0.0-py3-none-any.whl (188 kB)
#      ------------------------------------- 188.4/188.4 kB 11.1 MB/s eta 0:00:00
# Collecting pandas-profiling==2.3.0
#   Downloading pandas-profiling-2.3.0.tar.gz (127 kB)
#      -------------------------------------- 127.4/127.4 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 7.9 MB/s eta 0:00:00
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 6.1 MB/s eta 0:00:00
# Collecting DateTime==4.3
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
#      ---------------------------------------- 60.1/60.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: IPython in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pycaret==1.0) (8.4.0)
# Collecting gensim
#   Downloading gensim-4.2.0-cp38-cp38-win_amd64.whl (24.0 MB)
#      ---------------------------------------- 24.0/24.0 MB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pycaret==1.0) (7.6.5)
# Collecting pyod
#   Downloading pyod-1.0.5.tar.gz (137 kB)
#      -------------------------------------- 137.2/137.2 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn==0.22
#   Downloading scikit_learn-0.22-cp38-cp38-win_amd64.whl (6.3 MB)
#      ---------------------------------------- 6.3/6.3 MB 7.4 MB/s eta 0:00:00
# Collecting yellowbrick==1.0.1
#   Downloading yellowbrick-1.0.1-py3-none-any.whl (378 kB)
#      -------------------------------------- 379.0/379.0 kB 5.9 MB/s eta 0:00:00
# Collecting cufflinks==0.17.0
#   Downloading cufflinks-0.17.0.tar.gz (81 kB)
#      ---------------------------------------- 81.6/81.6 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kmodes==0.10.1
#   Downloading kmodes-0.10.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pycaret==1.0) (1.23.1)
# Collecting spacy
#   Downloading spacy-3.4.1-cp38-cp38-win_amd64.whl (12.1 MB)
#      ---------------------------------------- 12.1/12.1 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\users\wew12\appdata\roaming\python\python38\site-packages (from pycaret==1.0) (1.2.0)
# Collecting plotly==4.4.1
#   Downloading plotly-4.4.1-py2.py3-none-any.whl (7.3 MB)
#      ---------------------------------------- 7.3/7.3 MB 7.6 MB/s eta 0:00:00
# Collecting shap==0.32.1
#   Downloading shap-0.32.1.tar.gz (259 kB)
#      -------------------------------------- 259.2/259.2 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xgboost==0.90
#   Downloading xgboost-0.90-py2.py3-none-win_amd64.whl (18.3 MB)
#      ---------------------------------------- 18.3/18.3 MB 7.4 MB/s eta 0:00:00
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-win_amd64.whl (544 kB)
#      -------------------------------------- 544.4/544.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pycaret==1.0) (0.12.0)
# Requirement already satisfied: pandas in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pycaret==1.0) (1.5.0)
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ---------------------------------------- 88.2/88.2 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting catboost==0.20.2
#   Downloading catboost-0.20.2-cp38-none-win_amd64.whl (63.2 MB)
#      ---------------------------------------- 63.2/63.2 MB 7.0 MB/s eta 0:00:00
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      -------------------------------------- 636.8/636.8 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pycaret==1.0) (3.6.0)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 8.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting datefinder==0.7.0
#   Downloading datefinder-0.7.0-py2.py3-none-any.whl (8.8 kB)
# Collecting awscli
#   Downloading awscli-1.25.89-py3-none-any.whl (3.9 MB)
#      ---------------------------------------- 3.9/3.9 MB 7.6 MB/s eta 0:00:00
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp38-cp38-win_amd64.whl (152 kB)
#      -------------------------------------- 152.9/152.9 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from catboost==0.20.2->pycaret==1.0) (1.9.1)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB ? eta 0:00:00
# Requirement already satisfied: six in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from catboost==0.20.2->pycaret==1.0) (1.16.0)
# Collecting chart-studio>=1.0.0
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.4/64.4 kB 3.6 MB/s eta 0:00:00
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from cufflinks==0.17.0->pycaret==1.0) (59.8.0)
# Collecting regex>=2017.02.08
#   Using cached regex-2022.9.13-cp38-cp38-win_amd64.whl (267 kB)
# Requirement already satisfied: pytz in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from datefinder==0.7.0->pycaret==1.0) (2022.1)
# Requirement already satisfied: python-dateutil>=2.4.2 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from datefinder==0.7.0->pycaret==1.0) (2.8.2)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp38-cp38-win_amd64.whl (210 kB)
#      ------------------------------------- 210.8/210.8 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.8 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pandas-profiling==2.3.0->pycaret==1.0) (3.0.3)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting phik>=0.9.8
#   Downloading phik-0.12.2-cp38-cp38-win_amd64.whl (677 kB)
#      -------------------------------------- 677.3/677.3 kB 7.2 MB/s eta 0:00:00
# Collecting confuse>=1.0.0
#   Downloading confuse-2.0.0-py3-none-any.whl (24 kB)
# Collecting astropy
#   Downloading astropy-5.1-cp38-cp38-win_amd64.whl (6.5 MB)
#      ---------------------------------------- 6.5/6.5 MB 7.5 MB/s eta 0:00:00
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm>4.25.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from shap==0.32.1->pycaret==1.0) (4.64.1)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from yellowbrick==1.0.1->pycaret==1.0) (0.11.0)
# Requirement already satisfied: backcall in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (0.1.6)
# Requirement already satisfied: colorama in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (3.0.20)
# Requirement already satisfied: decorator in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (0.18.1)
# Requirement already satisfied: traitlets>=5 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from IPython->pycaret==1.0) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipywidgets->pycaret==1.0) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipywidgets->pycaret==1.0) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipywidgets->pycaret==1.0) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipywidgets->pycaret==1.0) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipywidgets->pycaret==1.0) (0.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from matplotlib->pycaret==1.0) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from matplotlib->pycaret==1.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from matplotlib->pycaret==1.0) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from matplotlib->pycaret==1.0) (4.37.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from matplotlib->pycaret==1.0) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from matplotlib->pycaret==1.0) (1.0.5)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ---------------------------------------- 79.6/79.6 kB 4.3 MB/s eta 0:00:00
# Collecting rsa<4.8,>=3.1.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting botocore==1.27.88
#   Downloading botocore-1.27.88-py3-none-any.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 7.7 MB/s eta 0:00:00
# Collecting docutils<0.17,>=0.10
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      -------------------------------------- 548.2/548.2 kB 8.7 MB/s eta 0:00:00
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting PyYAML<5.5,>=3.10
#   Downloading PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
#      ------------------------------------- 213.6/213.6 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from botocore==1.27.88->awscli->pycaret==1.0) (1.26.11)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting Cython==0.29.28
#   Downloading Cython-0.29.28-py2.py3-none-any.whl (983 kB)
#      -------------------------------------- 983.8/983.8 kB 7.8 MB/s eta 0:00:00
# Collecting smart-open>=1.8.1
#   Downloading smart_open-6.2.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.6/58.6 kB 3.0 MB/s eta 0:00:00
# Collecting mlxtend
#   Downloading mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 7.8 MB/s eta 0:00:00
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 7.8 MB/s eta 0:00:00
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Collecting numexpr
#   Downloading numexpr-2.8.3-cp38-cp38-win_amd64.whl (92 kB)
#      ---------------------------------------- 92.5/92.5 kB 5.1 MB/s eta 0:00:00
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      -------------------------------------- 829.2/829.2 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numba>=0.51 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pyod->pycaret==1.0) (0.56.2)
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp38-cp38-win_amd64.whl (9.1 MB)
#      ---------------------------------------- 9.1/9.1 MB 7.6 MB/s eta 0:00:00
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp38-cp38-win_amd64.whl (36 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Downloading thinc-8.1.2-cp38-cp38-win_amd64.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 8.2 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4
#   Downloading pydantic-1.9.2-cp38-cp38-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from spacy->pycaret==1.0) (2.28.1)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.4-cp38-cp38-win_amd64.whl (449 kB)
#      -------------------------------------- 449.9/449.9 kB 7.0 MB/s eta 0:00:00
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.8-cp38-cp38-win_amd64.whl (18 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ------------------------------------- 181.6/181.6 kB 10.7 MB/s eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.10-py2.py3-none-any.whl (21 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.7-cp38-cp38-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.7/96.7 kB ? eta 0:00:00
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.2-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (7.3.5)
# Requirement already satisfied: psutil in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (6.2)
# Requirement already satisfied: nest-asyncio in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (1.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jedi>=0.16->IPython->pycaret==1.0) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jinja2>=2.8->pandas-profiling==2.3.0->pycaret==1.0) (2.1.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==1.0) (4.16.0)
# Requirement already satisfied: jupyter_core in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==1.0) (4.10.0)
# Requirement already satisfied: fastjsonschema in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret==1.0) (2.16.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from numba>=0.51->pyod->pycaret==1.0) (0.39.1)
# Requirement already satisfied: importlib-metadata in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from numba>=0.51->pyod->pycaret==1.0) (5.0.0)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.6/58.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret==1.0) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4->spacy->pycaret==1.0) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->pycaret==1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->pycaret==1.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy->pycaret==1.0) (2022.9.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from rsa<4.8,>=3.1.2->awscli->pycaret==1.0) (0.4.8)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.2-py3-none-any.whl (32 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.8-cp38-cp38-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: notebook>=4.4.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (6.4.12)
# Collecting pyerfa>=2.0
#   Downloading pyerfa-2.0.0.1-cp38-cp38-win_amd64.whl (366 kB)
#      ------------------------------------- 366.4/366.4 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: executing in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from stack-data->IPython->pycaret==1.0) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from stack-data->IPython->pycaret==1.0) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from stack-data->IPython->pycaret==1.0) (0.2.2)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
#      -------------------------------------- 233.7/233.7 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.4.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret==1.0) (21.4.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret==1.0) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret==1.0) (5.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret==1.0) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pycaret==1.0) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from jupyter_core->nbformat>=4.2.0->ipywidgets->pycaret==1.0) (302)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.14.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from importlib-metadata->numba>=0.51->pyod->pycaret==1.0) (3.8.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (4.11.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.7.1)
# Requirement already satisfied: bleach in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (4.1.0)
# Requirement already satisfied: testpath in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.6.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret==1.0) (2.21)
# Building wheels for collected packages: cufflinks, pandas-profiling, shap, pyLDAvis, pyod, umap-learn, htmlmin, pynndescent, retrying, future, sklearn
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.0-py3-none-any.whl size=68556 sha256=14ae203855000b446b4ba107131a091b952700fe4a24a9223853c3998e73ce9d
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\ec\76\d5\88df45a08fc3118786a412f1df66d5f105d3e47fc23cddffd0
#   Building wheel for pandas-profiling (setup.py): started
#   Building wheel for pandas-profiling (setup.py): finished with status 'done'
#   Created wheel for pandas-profiling: filename=pandas_profiling-2.3.0-py2.py3-none-any.whl size=145063 sha256=941951f0d8151539f01fb459bb20e682a056a54c4f0e9b2dcff06252f342c52a
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\31\55\49\d146c0fc950e88c8df991c922c37223285511710bf363ff364
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.32.1-cp38-cp38-win_amd64.whl size=291470 sha256=b9c59e7d0f7a708886cb92c8ef0d2bca1d73fe05a64beb851b119b422f88fd5c
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\35\fc\68\3e78a9f683eab2f62c9c4109ecda4899690740d7845cb5726f
#   Building wheel for pyLDAvis (pyproject.toml): started
#   Building wheel for pyLDAvis (pyproject.toml): finished with status 'done'
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136882 sha256=fc307bf03a3c3f39d0a516ac080db0e386cc9e6f22d48b2a7dd3746a73fcd7de
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\90\61\ec\9dbe9efc3acf9c4e37ba70fbbcc3f3a0ebd121060aa593181a
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.0.5-py3-none-any.whl size=170258 sha256=a23c3072902c39a09b9460a538273d7d27902339254f3bec7056d41caa32d189
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\1c\ff\7e\9a03be54a5b71420ee3c3b57c31fcef7cf101395278855575f
#   Building wheel for umap-learn (setup.py): started
#   Building wheel for umap-learn (setup.py): finished with status 'done'
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=61cd36412d4ea22af34099dcf24b77eb51ebda20f2595b12bef0321c21baacfd
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\a9\3a\67\06a8950e053725912e6a8c42c4a3a241410f6487b8402542ea
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=0e62da6fb494ac0dab4d79946ab97ab5487e04377ca69811b68899dc56e79f93
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\23\14\6e\4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
#   Building wheel for pynndescent (setup.py): started
#   Building wheel for pynndescent (setup.py): finished with status 'done'
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=41e25e96ac5da43c63f029cf948875bff91671c3f5ef8c0c1826ddc38e6c2998
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\1b\38\fe\99e22fbae88abd1c5e8d99253cba6d1c590cc7a94408bff3bf
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=20767e00f4a42552c22f62ce6438437f0a40ffeba1c74bb5a64a35f93279c2e6
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=988fef910f9c4dd63f68896826de57cacb2e8fdfb95af8ea9f4244a9f35a5182
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\8e\70\28\3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=85887b8ea7d90afc36563902c0982b9c913d1ce5a5765f9afd10ae4d65ee934c
#   Stored in directory: c:\users\wew12\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built cufflinks pandas-profiling shap pyLDAvis pyod umap-learn htmlmin pynndescent retrying future sklearn
# Installing collected packages: wasabi, htmlmin, funcy, cymem, colorlover, zope.interface, spacy-loggers, spacy-legacy, smart-open, rsa, retrying, regex, PyYAML, pyerfa, pydantic, patsy, murmurhash, langcodes, jmespath, graphviz, future, docutils, Cython, colorama, catalogue, blis, xgboost, srsly, scikit-learn, preshed, plotly, numexpr, gensim, DateTime, datefinder, confuse, click, botocore, astropy, yellowbrick, wordcloud, typer, statsmodels, sklearn, shap, s3transfer, pynndescent, phik, nltk, mlxtend, lightgbm, kmodes, confection, chart-studio, catboost, umap-learn, thinc, textblob, pyod, pyLDAvis, pathy, missingno, awscli, spacy, pandas-profiling, cufflinks, pycaret
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.5
#     Uninstalling colorama-0.4.5:
#       Successfully uninstalled colorama-0.4.5
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.2
#     Uninstalling scikit-learn-1.1.2:
#       Successfully uninstalled scikit-learn-1.1.2
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.10.0
#     Uninstalling plotly-5.10.0:
#       Successfully uninstalled plotly-5.10.0
# Successfully installed Cython-0.29.28 DateTime-4.3 PyYAML-5.4.1 astropy-5.1 awscli-1.25.89 blis-0.7.8 botocore-1.27.88 catalogue-2.0.8 catboost-0.20.2 chart-studio-1.1.0 click-8.1.3 colorama-0.4.4 colorlover-0.3.0 confection-0.0.2 confuse-2.0.0 cufflinks-0.17.0 cymem-2.0.6 datefinder-0.7.0 docutils-0.16 funcy-1.17 future-0.18.2 gensim-4.2.0 graphviz-0.20.1 htmlmin-0.1.12 jmespath-1.0.1 kmodes-0.10.1 langcodes-3.3.0 lightgbm-2.3.1 missingno-0.5.1 mlxtend-0.19.0 murmurhash-1.0.8 nltk-3.7 numexpr-2.8.3 pandas-profiling-2.3.0 pathy-0.6.2 patsy-0.5.2 phik-0.12.2 plotly-4.4.1 preshed-3.0.7 pyLDAvis-3.3.1 pycaret-1.0.0 pydantic-1.9.2 pyerfa-2.0.0.1 pynndescent-0.5.7 pyod-1.0.5 regex-2022.9.13 retrying-1.3.3 rsa-4.7.2 s3transfer-0.6.0 scikit-learn-0.22 shap-0.32.1 sklearn-0.0 smart-open-5.2.1 spacy-3.4.1 spacy-legacy-3.0.10 spacy-loggers-1.0.3 srsly-2.4.4 statsmodels-0.13.2 textblob-0.17.1 thinc-8.1.2 typer-0.4.2 umap-learn-0.5.3 wasabi-0.10.1 wordcloud-1.8.2.2 xgboost-0.90 yellowbrick-1.0.1 zope.interface-5.4.0
# Collecting scipy==1.2
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [132 lines of output]
#       C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py:114: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#         import imp
#       C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py:468: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.core import setup
#       Running from scipy source directory.
#       INFO: lapack_opt_info:
#       INFO: lapack_armpl_info:
#       INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       INFO: customize MSVCCompiler
#       INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_mkl_info:
#       INFO:   libraries mkl_rt not found in ['C:/Users/wew12/Anaconda3/envs/pytorch17_p38\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_lapack_info:
#       INFO:   libraries openblas not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       INFO: customize GnuFCompiler
#       WARN: Could not locate executable g77
#       WARN: Could not locate executable f77
#       INFO: customize IntelVisualFCompiler
#       WARN: Could not locate executable ifort
#       WARN: Could not locate executable ifl
#       INFO: customize AbsoftFCompiler
#       WARN: Could not locate executable f90
#       INFO: customize CompaqVisualFCompiler
#       WARN: Could not locate executable DF
#       INFO: customize IntelItaniumVisualFCompiler
#       WARN: Could not locate executable efl
#       INFO: customize Gnu95FCompiler
#       WARN: Could not locate executable gfortran
#       WARN: Could not locate executable f95
#       INFO: customize G95FCompiler
#       WARN: Could not locate executable g95
#       INFO: customize IntelEM64VisualFCompiler
#       INFO: customize IntelEM64TFCompiler
#       WARN: Could not locate executable efort
#       WARN: Could not locate executable efc
#       INFO: customize PGroupFlangCompiler
#       WARN: Could not locate executable flang
#       WARN: don't know how to compile Fortran code on platform 'nt'
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_clapack_info:
#       INFO:   libraries openblas,lapack not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: flame_info:
#       INFO:   libraries flame not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: accelerate_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas,tatlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries tatlas,tatlas not found in C:\
#       INFO:   libraries tatlas,tatlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries tatlas,tatlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_info:
#       INFO:   libraries satlas,satlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries satlas,satlas not found in C:\
#       INFO:   libraries satlas,satlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries satlas,satlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries f77blas,cblas,atlas not found in C:\
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_info:
#       INFO:   libraries lapack not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib\site-packages\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO: lapack_src_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib\site-packages\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO:   NOT AVAILABLE
#       INFO:
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py", line 492, in <module>
#           setup_package()
#         File "C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py", line 488, in setup_package
#           setup(**metadata)
#         File "C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib\site-packages\numpy\distutils\core.py", line 135, in setup
#           config = configuration()
#         File "C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py", line 395, in configuration
#           raise NotFoundError(msg)
#       numpy.distutils.system_info.NotFoundError: No lapack/blas resources found.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scipy
#   error: subprocess-exited-with-error
#
#   × python setup.py clean did not run successfully.
#   │ exit code: 1
#   ╰─> [11 lines of output]
#       C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py:114: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#         import imp
#
#       `setup.py clean` is not supported, use one of the following instead:
#
#         - `git clean -xdf` (cleans all files)
#         - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                             files that aren't checked into the git repo)
#
#       Add `--force` to your command to use it anyway if you must (unsupported).
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for scipy
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for scipy did not run successfully.
#   │ exit code: 1
#   ╰─> [141 lines of output]
#       C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py:114: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#         import imp
#
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install scipy`   (last SciPy release on PyPI)
#
#
#       C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py:468: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.core import setup
#       Running from scipy source directory.
#       INFO: lapack_opt_info:
#       INFO: lapack_armpl_info:
#       INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       INFO: customize MSVCCompiler
#       INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_mkl_info:
#       INFO:   libraries mkl_rt not found in ['C:/Users/wew12/Anaconda3/envs/pytorch17_p38\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_lapack_info:
#       INFO:   libraries openblas not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       INFO: customize GnuFCompiler
#       WARN: Could not locate executable g77
#       WARN: Could not locate executable f77
#       INFO: customize IntelVisualFCompiler
#       WARN: Could not locate executable ifort
#       WARN: Could not locate executable ifl
#       INFO: customize AbsoftFCompiler
#       WARN: Could not locate executable f90
#       INFO: customize CompaqVisualFCompiler
#       WARN: Could not locate executable DF
#       INFO: customize IntelItaniumVisualFCompiler
#       WARN: Could not locate executable efl
#       INFO: customize Gnu95FCompiler
#       WARN: Could not locate executable gfortran
#       WARN: Could not locate executable f95
#       INFO: customize G95FCompiler
#       WARN: Could not locate executable g95
#       INFO: customize IntelEM64VisualFCompiler
#       INFO: customize IntelEM64TFCompiler
#       WARN: Could not locate executable efort
#       WARN: Could not locate executable efc
#       INFO: customize PGroupFlangCompiler
#       WARN: Could not locate executable flang
#       WARN: don't know how to compile Fortran code on platform 'nt'
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: openblas_clapack_info:
#       INFO:   libraries openblas,lapack not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: flame_info:
#       INFO:   libraries flame not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: accelerate_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries tatlas,tatlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries tatlas,tatlas not found in C:\
#       INFO:   libraries tatlas,tatlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries tatlas,tatlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_3_10_info:
#       INFO:   libraries satlas,satlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries satlas,satlas not found in C:\
#       INFO:   libraries satlas,satlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries satlas,satlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_threads_info:
#       INFO: Setting PTATLAS=ATLAS
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries ptf77blas,ptcblas,atlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_threads_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: atlas_info:
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib
#       INFO:   libraries f77blas,cblas,atlas not found in C:\
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\wew12\Anaconda3\envs\pytorch17_p38\libs
#       INFO:   libraries f77blas,cblas,atlas not found in C:\Users\wew12\Anaconda3\Library\lib
#       INFO: <class 'numpy.distutils.system_info.atlas_info'>
#       INFO:   NOT AVAILABLE
#       INFO:
#       INFO: lapack_info:
#       INFO:   libraries lapack not found in ['C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\lib', 'C:\\', 'C:\\Users\\wew12\\Anaconda3\\envs\\pytorch17_p38\\libs', 'C:\\Users\\wew12\\Anaconda3\\Library\\lib']
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib\site-packages\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO: lapack_src_info:
#       INFO:   NOT AVAILABLE
#       INFO:
#       C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib\site-packages\numpy\distutils\system_info.py:1902: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         return getattr(self, '_calc_info_{}'.format(name))()
#       INFO:   NOT AVAILABLE
#       INFO:
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py", line 492, in <module>
#           setup_package()
#         File "C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py", line 488, in setup_package
#           setup(**metadata)
#         File "C:\Users\wew12\Anaconda3\envs\pytorch17_p38\lib\site-packages\numpy\distutils\core.py", line 135, in setup
#           config = configuration()
#         File "C:\Users\wew12\AppData\Local\Temp\pip-install-v1yb059m\scipy_8c757d334ad54c9e9dbc279863e0a77f\setup.py", line 395, in configuration
#           raise NotFoundError(msg)
#       numpy.distutils.system_info.NotFoundError: No lapack/blas resources found.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   WARNING: No metadata found in c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> scipy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#   Downloading scipy-1.2.0.tar.gz (23.3 MB)
#      ---------------------------------------- 23.3/23.3 MB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: scipy
#   Building wheel for scipy (setup.py): started
#   Building wheel for scipy (setup.py): finished with status 'error'
#   Running setup.py clean for scipy
# Failed to build scipy
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.1
#     Uninstalling scipy-1.9.1:
#       Successfully uninstalled scipy-1.9.1
#   Running setup.py install for scipy: started
#   Running setup.py install for scipy: finished with status 'error'
#   Rolling back uninstall of scipy
#   Moving to c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages\scipy-1.9.1.dist-info\
#    from C:\Users\wew12\Anaconda3\envs\pytorch17_p38\Lib\site-packages\~cipy-1.9.1.dist-info
#   Moving to c:\users\wew12\anaconda3\envs\pytorch17_p38\lib\site-packages\scipy\
#    from C:\Users\wew12\Anaconda3\envs\pytorch17_p38\Lib\site-packages\~cipy

# %%
#pycaret에서 제공하는 'juice' 데이터
from pycaret.datasets import get_data
data = get_data('juice')
data.info()

# %%
from pycaret.datasets import get_data 
from pycaret.classification import *
from pycaret.utils import check_metric
setup_clf = setup(data=data, target='Purchase')

# %%
# ML 모델 성능 비교
top = compare_models()
top

# %%
from pycaret.regression import *
from pycaret.datasets import get_data
dataset = get_data('diamond')
exp = setup(dataset, target='Price')
reg_top = compare_models()
reg_top

# %%
# !pip install pycaret==2.0.0
# !pip install scikit-learn==0.23.2

# %%
# pycaret 버전
import pycaret
print('PyCaret: %s' % pycaret.__version__)

# %%
from pandas import read_csv

# pycaret classification 모듈
from pycaret.classification import setup

# pycaret classification 모델들을 비교하기 위한 모듈
from pycaret.classification import compare_models

# sonar 데이터셋
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'

# 데이터셋 로드
df = read_csv(url, header=None)
# 컬럼 갯수
n_cols = df.shape[1]

# 컬럼명 String으로 반환
df.columns = [str(i) for i in range(n_cols)]
# 데이터셋 설정
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)
# 모델 학습
best = compare_models()
# best 모델 확인
print(best)

# %%
# !pip3 install bayesian-optimization

# %%
from sklearn.metrics import r2_score, mean_squared_error
import xgboost as xgb
# MAPE 
def mean_absolute_percentage_error(y_test, y_pred):
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# 탐색 대상 함수 (XGBRegressor)
def XGB_cv(max_depth,learning_rate, n_estimators):

    # 모델 정의
    model = xgb.XGBRegressor(max_depth=int(max_depth),
                            learning_rate=learning_rate,
                            n_estimators=int(n_estimators)
                            )
    # 모델 훈련
    model.fit(X_train, y_train)

    # 예측값 출력
    y_pred= model.predict(X_test)
    r2 = r2_score(y_test, y_pred)

    # 오차 최적화로 사용할 metric 반환 (베이지안은 이것을 성능수치로 받아들이게됨)
    return r2

# %%
#  bayesian-optimization 라이브러리의 BayesianOptimization 클래스 import
from bayes_opt import BayesianOptimization
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

X, y = make_moons(n_samples=500, noise=0.30, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# 실험해보고자하는 hyperparameter 집합
# max_depth(int, default: 3): 기본 학습자를 위한 최대 트리 깊이
# learning_rate(float, default: 0.1) : Boosting 학습률
# n_estimators(int, default: 100) : fit하기 위한 Boosted tree의 수

pbounds = {'max_depth': (3, 7),
            'learning_rate': (0.001, 0.2),
            'n_estimators': (5000, 10000)
            }

# Bayesian optimization 객체 생성
# f : 탐색 대상 함수, pbounds : hyperparameter 집합
# verbose = 2 항상 출력, verbose = 1 최댓값일 때 출력, verbose = 0 출력 안함
bo=BayesianOptimization(f=XGB_cv, pbounds=pbounds, verbose=2, random_state=1 )    

# 메소드를 이용해 최대화 과정 수행
# init_points :  초기 Random Search 갯수
# n_iter : 반복 횟수 (몇개의 입력값-함숫값 점들을 확인할지! 많을 수록 정확한 값을 얻을 수 있다.)
# acq : Acquisition Function들 중 Expected Improvement(EI) 를 사용
# xi : exploration 강도 (기본값은 0.0)
bo.maximize(init_points=2, n_iter=10, acq='ei', xi=0.01)

# ‘iter’는 반복 회차, ‘target’은 목적 함수의 값, 나머지는 입력값을 나타냄. 
# 현재 회차 이전까지 조사된 함숫값들과 비교하여, 현재 회차에 최댓값이 얻어진 경우, 
# bayesian-optimization 라이브러리는 이를 자동으로 다른 색 글자로 표시하는 것을 확인.

# 찾은 파라미터 값 확인
print(bo.max)
